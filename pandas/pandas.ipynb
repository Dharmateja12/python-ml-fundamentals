# %%
import pandas as pd

# %%
housing["ocean_proximity"] = housing["ocean_proximity"].astype("category")
# Loads the full CSV into RAM in one go — fine for small/medium files,
    # but will fail (MemoryError) if the file is too large to fit in available memory.
    # For big files, consider chunksize=... or nrows=... to read partially.

# %%
# housing.info()
# housing.info(memory_usage="deep")  # shows exact memory usage instead of estimate
housing.memory_usage(deep=True)  # shows exact memory usage instead of estimate

# %% [markdown]
# category dtype stores each unique string just once, then uses small integer codes to reference them per row — much cheaper than storing the full string repeatedly for all 20,640 rows.
